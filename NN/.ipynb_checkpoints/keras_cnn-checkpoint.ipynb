# %%
import tensorflow as tf
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt
import PIL
import tensorflow.keras as keras


# !rm -rf ./keras
train_data = np.zeros((165, 64*64))
train_labels = np.zeros((165,1), dtype= np.uint8)

for people in range(1,16):
    for face in range(1,12):
        if(people >= 10):
            path = './Yale2/subject%d_%d.bmp' % (people, face)
        else:
            path = './Yale2/subject0%d_%d.bmp' % (people, face)
        oriImage = PIL.Image.open(path)
        oriImage = oriImage.resize((64,64))
        imageArray = np.array(oriImage)
        imageArray = imageArray.T
        imageVec = np.reshape(imageArray, imageArray.shape[0] * imageArray.shape[1])
        # print(imageArray.shape)
        # print(imageBigDataORL.shape)
#             print((people - 1) * 10 + face)
        train_data[(people - 1) * 11 + face - 1] = imageVec
        train_labels[(people - 1) * 11 + face - 1] = people
    

print(train_data.shape)
print(train_labels.shape)
plt.figure()
plt.imshow(train_data[0].reshape([64,64]))

train_labels = train_labels - 1

np.random.seed(100)
train_data = np.random.permutation(train_data[50:,:])
np.random.seed(100)
train_labels = np.random.permutation(train_labels[50:])
test_data = train_data[0:50,:]
test_labels = train_labels[0:50]
np.random.seed(200)
test_data = np.random.permutation(test_data)
np.random.seed(200)
test_labels = np.random.permutation(test_labels)

#将标签转为one_hot类型
def label_to_one_hot(labels_dense, num_classes=15):
    num_labels = labels_dense.shape[0]
    print(num_labels)
    index_offset = np.arange(num_labels) * num_classes
    print(index_offset)
    labels_one_hot = np.zeros((num_labels, num_classes))
    print(labels_dense.ravel())
    labels_one_hot.flat[index_offset + labels_dense.ravel()] = 1
    return labels_one_hot

#将图片转为灰度图
def to4d(img):
    return img.reshape(img.shape[0],64,64,1).astype(np.float32)/255

train_data = to4d(train_data)
train_labels = label_to_one_hot(train_labels,15)
test_data = to4d(test_data)
test_labels = label_to_one_hot(test_labels,15)
plt.figure()
plt.imshow(train_data[0,:,:,0])
plt.title(np.argmax(train_labels[0]))
# Out:
# (165, 4096)
# (165, 1)
# 115
# [   0   15   30   45   60   75   90  105  120  135  150  165  180  195
#   210  225  240  255  270  285  300  315  330  345  360  375  390  405
#   420  435  450  465  480  495  510  525  540  555  570  585  600  615
#   630  645  660  675  690  705  720  735  750  765  780  795  810  825
#   840  855  870  885  900  915  930  945  960  975  990 1005 1020 1035
#  1050 1065 1080 1095 1110 1125 1140 1155 1170 1185 1200 1215 1230 1245
#  1260 1275 1290 1305 1320 1335 1350 1365 1380 1395 1410 1425 1440 1455
#  1470 1485 1500 1515 1530 1545 1560 1575 1590 1605 1620 1635 1650 1665
#  1680 1695 1710]
# [12 11  9  7 13 11  6  7  7  6 11  9  8  7 13  6 14 11  8 13  7  9 11  6
#  10 11  5 13  5  7 14 13  7  6 11 13  6 10  5  4  5 14 12 11 11  8 10  8
#  12  9 12  8 12 14  6 14 10 13 10  4  6  8  8  8  8 14 14  7  9 12 14 10
#   6 12 11  9 13 10 10  8  9  5 14  9 12 12  5  4  7  4  7  4 12  5  6  9
#  10  5 14  7  5 14 10  9 13  9 13  5  8 11 12 13 10  6  5]
# 50
# [  0  15  30  45  60  75  90 105 120 135 150 165 180 195 210 225 240 255
#  270 285 300 315 330 345 360 375 390 405 420 435 450 465 480 495 510 525
#  540 555 570 585 600 615 630 645 660 675 690 705 720 735]
# [ 6  7 13  5  7  9  8 11 11  7 11  9 10 14 11  5  7 12  7 10 11 13  8  7
#   4 11 13 10  9  6 12  6 11  6  5  7 11  6  9  8 13 13 11  6  8 12 13 14
#  14  5]
# Text(0.5,1,'12')

# %%
# conv1 = tf.layers.conv2d(inputs=xs,filters=32,kernel_size=2,strides=1,padding='same',activation=tf.nn.relu)
# pool1 = tf.layers.max_pooling2d(conv1,pool_size=2,strides=2)
# conv2 = tf.layers.conv2d(pool1,filters=72,kernel_size=2,strides=1,padding='same',activation=tf.nn.relu)
# pool2 = tf.layers.max_pooling2d(conv2,pool_size=2,strides=2)
# flat = tf.reshape(pool2,[-1,16*16*72])
# dense = tf.layers.dense(flat,512,tf.nn.relu)
# dropout = tf.nn.dropout(dense,keep_prob)
# output = tf.layers.dense(dropout,15)

model = keras.models.Sequential()
model.add(keras.layers.Conv2D(32, 2, padding='same', activation='relu',name='conv1'))
model.add(keras.layers.MaxPooling2D(strides=2, name='pool1'))
model.add(keras.layers.Conv2D(72, 2, padding='same', activation='relu',name='conv2'))
model.add(keras.layers.MaxPooling2D(strides=2, name='pool2'))
model.add(keras.layers.Flatten(name='flatten'))
# model.add(keras.layers.Dense(400, activation='relu', name='hidden_layer_2'))
model.add(keras.layers.Dense(512, activation='relu',name='dense'))
model.add(keras.layers.Dropout(0.25, name='drop'))
model.add(keras.layers.Dense(15, activation='softmax',name='output'))
model.compile(loss='categorical_crossentropy', optimizer=tf.train.AdamOptimizer(0.0001), metrics=['accuracy','mae'])



tb_cb = keras.callbacks.TensorBoard(log_dir='./keras',write_images = 1, histogram_freq=1,write_grads=1)

cbks = [tb_cb]
history = model.fit(train_data, train_labels, batch_size=115, nb_epoch=55, 
verbose=1, callbacks=cbks, validation_data=(test_data, test_labels))

model.summary()
# Out:
# WARNING:tensorflow:The `nb_epoch` argument in `fit` has been renamed `epochs`.
# Train on 115 samples, validate on 50 samples
# Epoch 1/55
# 115/115 [==============================] - 1s 7ms/step - loss: 2.6972 - acc: 0.0435 - mean_absolute_error: 0.1243 - val_loss: 2.6274 - val_acc: 0.1600 - val_mean_absolute_error: 0.1237
# Epoch 2/55
# 115/115 [==============================] - 0s 4ms/step - loss: 2.6298 - acc: 0.2348 - mean_absolute_error: 0.1237 - val_loss: 2.5714 - val_acc: 0.4000 - val_mean_absolute_error: 0.1231
# Epoch 3/55
# 115/115 [==============================] - 0s 4ms/step - loss: 2.5748 - acc: 0.3304 - mean_absolute_error: 0.1232 - val_loss: 2.5252 - val_acc: 0.3000 - val_mean_absolute_error: 0.1226
# Epoch 4/55
# 115/115 [==============================] - 1s 5ms/step - loss: 2.5309 - acc: 0.3130 - mean_absolute_error: 0.1227 - val_loss: 2.4824 - val_acc: 0.3400 - val_mean_absolute_error: 0.1222
# Epoch 5/55
# 115/115 [==============================] - 1s 4ms/step - loss: 2.4776 - acc: 0.3478 - mean_absolute_error: 0.1221 - val_loss: 2.4403 - val_acc: 0.3800 - val_mean_absolute_error: 0.1216
# Epoch 6/55
# 115/115 [==============================] - 1s 5ms/step - loss: 2.4361 - acc: 0.3478 - mean_absolute_error: 0.1215 - val_loss: 2.4000 - val_acc: 0.4800 - val_mean_absolute_error: 0.1211
# Epoch 7/55
# 115/115 [==============================] - 1s 5ms/step - loss: 2.4062 - acc: 0.3391 - mean_absolute_error: 0.1211 - val_loss: 2.3618 - val_acc: 0.6000 - val_mean_absolute_error: 0.1206
# Epoch 8/55
# 115/115 [==============================] - 1s 5ms/step - loss: 2.3468 - acc: 0.4435 - mean_absolute_error: 0.1203 - val_loss: 2.3242 - val_acc: 0.6600 - val_mean_absolute_error: 0.1201
# Epoch 9/55
# 115/115 [==============================] - 1s 5ms/step - loss: 2.3264 - acc: 0.3391 - mean_absolute_error: 0.1199 - val_loss: 2.2869 - val_acc: 0.6600 - val_mean_absolute_error: 0.1195
# Epoch 10/55
# 115/115 [==============================] - 1s 5ms/step - loss: 2.2693 - acc: 0.4435 - mean_absolute_error: 0.1190 - val_loss: 2.2501 - val_acc: 0.6600 - val_mean_absolute_error: 0.1189
# Epoch 11/55
# 115/115 [==============================] - 1s 5ms/step - loss: 2.2358 - acc: 0.4783 - mean_absolute_error: 0.1185 - val_loss: 2.2137 - val_acc: 0.6600 - val_mean_absolute_error: 0.1182
# Epoch 12/55
# 115/115 [==============================] - 1s 4ms/step - loss: 2.2154 - acc: 0.4522 - mean_absolute_error: 0.1180 - val_loss: 2.1778 - val_acc: 0.6400 - val_mean_absolute_error: 0.1176
# Epoch 13/55
# 115/115 [==============================] - 1s 4ms/step - loss: 2.1935 - acc: 0.4783 - mean_absolute_error: 0.1175 - val_loss: 2.1411 - val_acc: 0.6400 - val_mean_absolute_error: 0.1169
# Epoch 14/55
# 115/115 [==============================] - 1s 4ms/step - loss: 2.1446 - acc: 0.4696 - mean_absolute_error: 0.1167 - val_loss: 2.1037 - val_acc: 0.6400 - val_mean_absolute_error: 0.1161
# Epoch 15/55
# 115/115 [==============================] - 0s 4ms/step - loss: 2.1364 - acc: 0.5043 - mean_absolute_error: 0.1162 - val_loss: 2.0670 - val_acc: 0.6800 - val_mean_absolute_error: 0.1154
# Epoch 16/55
# 115/115 [==============================] - 1s 4ms/step - loss: 2.0815 - acc: 0.5565 - mean_absolute_error: 0.1152 - val_loss: 2.0303 - val_acc: 0.6800 - val_mean_absolute_error: 0.1146
# Epoch 17/55
# 115/115 [==============================] - 1s 5ms/step - loss: 2.0783 - acc: 0.4522 - mean_absolute_error: 0.1150 - val_loss: 1.9950 - val_acc: 0.8400 - val_mean_absolute_error: 0.1138
# Epoch 18/55
# 115/115 [==============================] - 0s 4ms/step - loss: 2.0051 - acc: 0.5652 - mean_absolute_error: 0.1132 - val_loss: 1.9607 - val_acc: 0.9000 - val_mean_absolute_error: 0.1131
# Epoch 19/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.9719 - acc: 0.5913 - mean_absolute_error: 0.1128 - val_loss: 1.9260 - val_acc: 0.9000 - val_mean_absolute_error: 0.1122
# Epoch 20/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.9372 - acc: 0.5652 - mean_absolute_error: 0.1118 - val_loss: 1.8903 - val_acc: 0.9000 - val_mean_absolute_error: 0.1113
# Epoch 21/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.8934 - acc: 0.6957 - mean_absolute_error: 0.1108 - val_loss: 1.8551 - val_acc: 0.9200 - val_mean_absolute_error: 0.1104
# Epoch 22/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.8609 - acc: 0.6261 - mean_absolute_error: 0.1097 - val_loss: 1.8198 - val_acc: 0.9200 - val_mean_absolute_error: 0.1095
# Epoch 23/55
# 115/115 [==============================] - 1s 4ms/step - loss: 1.8331 - acc: 0.6696 - mean_absolute_error: 0.1088 - val_loss: 1.7850 - val_acc: 0.9200 - val_mean_absolute_error: 0.1086
# Epoch 24/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.8039 - acc: 0.6609 - mean_absolute_error: 0.1079 - val_loss: 1.7502 - val_acc: 0.9200 - val_mean_absolute_error: 0.1076
# Epoch 25/55
# 115/115 [==============================] - 1s 4ms/step - loss: 1.7851 - acc: 0.6348 - mean_absolute_error: 0.1073 - val_loss: 1.7157 - val_acc: 0.9400 - val_mean_absolute_error: 0.1066
# Epoch 26/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.7344 - acc: 0.7478 - mean_absolute_error: 0.1060 - val_loss: 1.6813 - val_acc: 0.9400 - val_mean_absolute_error: 0.1056
# Epoch 27/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.7025 - acc: 0.6870 - mean_absolute_error: 0.1049 - val_loss: 1.6467 - val_acc: 0.9400 - val_mean_absolute_error: 0.1046
# Epoch 28/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.6545 - acc: 0.7565 - mean_absolute_error: 0.1037 - val_loss: 1.6112 - val_acc: 0.9400 - val_mean_absolute_error: 0.1035
# Epoch 29/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.6233 - acc: 0.7478 - mean_absolute_error: 0.1026 - val_loss: 1.5753 - val_acc: 0.9400 - val_mean_absolute_error: 0.1024
# Epoch 30/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.6153 - acc: 0.7304 - mean_absolute_error: 0.1020 - val_loss: 1.5400 - val_acc: 0.9600 - val_mean_absolute_error: 0.1012
# Epoch 31/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.5612 - acc: 0.7130 - mean_absolute_error: 0.1002 - val_loss: 1.5049 - val_acc: 0.9600 - val_mean_absolute_error: 0.1000
# Epoch 32/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.4796 - acc: 0.8000 - mean_absolute_error: 0.0979 - val_loss: 1.4686 - val_acc: 0.9600 - val_mean_absolute_error: 0.0988
# Epoch 33/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.5457 - acc: 0.7913 - mean_absolute_error: 0.0994 - val_loss: 1.4326 - val_acc: 0.9600 - val_mean_absolute_error: 0.0975
# Epoch 34/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.4660 - acc: 0.7478 - mean_absolute_error: 0.0966 - val_loss: 1.3958 - val_acc: 0.9600 - val_mean_absolute_error: 0.0961
# Epoch 35/55
# 115/115 [==============================] - 1s 4ms/step - loss: 1.4132 - acc: 0.7826 - mean_absolute_error: 0.0949 - val_loss: 1.3592 - val_acc: 0.9600 - val_mean_absolute_error: 0.0948
# Epoch 36/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.3996 - acc: 0.8000 - mean_absolute_error: 0.0944 - val_loss: 1.3242 - val_acc: 0.9600 - val_mean_absolute_error: 0.0935
# Epoch 37/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.3470 - acc: 0.8000 - mean_absolute_error: 0.0931 - val_loss: 1.2902 - val_acc: 0.9600 - val_mean_absolute_error: 0.0922
# Epoch 38/55
# 115/115 [==============================] - 1s 4ms/step - loss: 1.3266 - acc: 0.8261 - mean_absolute_error: 0.0917 - val_loss: 1.2572 - val_acc: 0.9600 - val_mean_absolute_error: 0.0909
# Epoch 39/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.2593 - acc: 0.8522 - mean_absolute_error: 0.0891 - val_loss: 1.2243 - val_acc: 0.9600 - val_mean_absolute_error: 0.0896
# Epoch 40/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.2503 - acc: 0.8087 - mean_absolute_error: 0.0893 - val_loss: 1.1893 - val_acc: 0.9600 - val_mean_absolute_error: 0.0881
# Epoch 41/55
# 115/115 [==============================] - 1s 5ms/step - loss: 1.2055 - acc: 0.8348 - mean_absolute_error: 0.0871 - val_loss: 1.1542 - val_acc: 0.9600 - val_mean_absolute_error: 0.0866
# Epoch 42/55
# 115/115 [==============================] - 1s 4ms/step - loss: 1.1549 - acc: 0.8435 - mean_absolute_error: 0.0845 - val_loss: 1.1174 - val_acc: 0.9600 - val_mean_absolute_error: 0.0850
# Epoch 43/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.1253 - acc: 0.8783 - mean_absolute_error: 0.0836 - val_loss: 1.0791 - val_acc: 0.9600 - val_mean_absolute_error: 0.0832
# Epoch 44/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.0975 - acc: 0.8870 - mean_absolute_error: 0.0821 - val_loss: 1.0409 - val_acc: 0.9600 - val_mean_absolute_error: 0.0814
# Epoch 45/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.1074 - acc: 0.8609 - mean_absolute_error: 0.0828 - val_loss: 1.0038 - val_acc: 0.9600 - val_mean_absolute_error: 0.0796
# Epoch 46/55
# 115/115 [==============================] - 0s 4ms/step - loss: 1.0490 - acc: 0.8783 - mean_absolute_error: 0.0792 - val_loss: 0.9693 - val_acc: 0.9600 - val_mean_absolute_error: 0.0778
# Epoch 47/55
# 115/115 [==============================] - 0s 4ms/step - loss: 0.9914 - acc: 0.8870 - mean_absolute_error: 0.0767 - val_loss: 0.9373 - val_acc: 0.9600 - val_mean_absolute_error: 0.0762
# Epoch 48/55
# 115/115 [==============================] - 1s 5ms/step - loss: 0.9723 - acc: 0.9130 - mean_absolute_error: 0.0758 - val_loss: 0.9061 - val_acc: 0.9600 - val_mean_absolute_error: 0.0745
# Epoch 49/55
# 115/115 [==============================] - 1s 4ms/step - loss: 0.9213 - acc: 0.9043 - mean_absolute_error: 0.0728 - val_loss: 0.8720 - val_acc: 0.9600 - val_mean_absolute_error: 0.0726
# Epoch 50/55
# 115/115 [==============================] - 1s 4ms/step - loss: 0.8942 - acc: 0.9130 - mean_absolute_error: 0.0719 - val_loss: 0.8387 - val_acc: 0.9600 - val_mean_absolute_error: 0.0708
# Epoch 51/55
# 115/115 [==============================] - 1s 5ms/step - loss: 0.8984 - acc: 0.8957 - mean_absolute_error: 0.0717 - val_loss: 0.8072 - val_acc: 0.9600 - val_mean_absolute_error: 0.0689
# Epoch 52/55
# 115/115 [==============================] - 1s 4ms/step - loss: 0.8844 - acc: 0.8609 - mean_absolute_error: 0.0709 - val_loss: 0.7770 - val_acc: 0.9600 - val_mean_absolute_error: 0.0671
# Epoch 53/55
# 115/115 [==============================] - 1s 5ms/step - loss: 0.8498 - acc: 0.8957 - mean_absolute_error: 0.0691 - val_loss: 0.7480 - val_acc: 0.9800 - val_mean_absolute_error: 0.0654
# Epoch 54/55
# 115/115 [==============================] - 1s 5ms/step - loss: 0.7941 - acc: 0.9478 - mean_absolute_error: 0.0660 - val_loss: 0.7194 - val_acc: 0.9800 - val_mean_absolute_error: 0.0637
# Epoch 55/55
# 115/115 [==============================] - 0s 4ms/step - loss: 0.7612 - acc: 0.9391 - mean_absolute_error: 0.0642 - val_loss: 0.6929 - val_acc: 0.9800 - val_mean_absolute_error: 0.0620
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 64, 64, 32)        160
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2 (Conv2D)               (None, 32, 32, 72)        9288
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 16, 16, 72)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               9437696
# _________________________________________________________________
# drop (Dropout)               (None, 512)               0
# _________________________________________________________________
# output (Dense)               (None, 15)                7695
# =================================================================
# Total params: 9,454,839
# Trainable params: 9,454,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
! tensorboard --logdir ./keras
# Out:
# TensorBoard 1.9.0 at http://KhazeusMBP.local:6006 (Press CTRL+C to quit)
